# %%
# Dataset Link - "C:\Users\kavin\Downloads\archive\googleplaystore.csv"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\kavin\Downloads\archive\googleplaystore.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# # 1. Display Top 5 Rows of The Dataset

# %%
df.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# # 2. Check the Last 3 Rows of The Dataset

# %%
df.tail(3)
# Out:
#                                                  App             Category  \
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10838          2.2 and up
# 10839  Varies with device
# ...

# %% [markdown]
# # 3. Find Shape of Our Dataset (Number of Rows & Number of Columns)

# %%
df.shape
# Out:
# (10841, 13)

# %%
print("Number of rows : ", df.shape[0])
print("Number of rows : ", df.shape[1])
# Out:
# Number of rows :  10841
# Number of rows :  13

# %% [markdown]
# # 4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# # 5. Get Overall Statistics About The Dataframe

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# # 6. Total Number of App Titles Contain Astrology

# %%
df.head(20)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# ...

# %%
df["App"].str.contains("astrology", case=False)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840     True
# Name: App, Length: 10841, dtype: bool

# %%
df[df["App"].str.contains("astrology", case=False)].count()
# Out:
# App               3
# Category          3
# Rating            3
# Reviews           3
# Size              3
# Installs          3
# Type              3
# Price             3
# Content Rating    3
# Genres            3
# Last Updated      3
# Current Ver       3
# Android Ver       3
# dtype: int64

# %%
len(df[df["App"].str.contains("astrology", case=False)])
# Out:
# 3

# %% [markdown]
# # 7. Find Average App Rating

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df["Rating"].mean()
# Out:
# np.float64(4.193338315362443)

# %% [markdown]
# # 8.  Find Total Number of Unique Category

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df["Category"].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df["Category"].nunique()
# Out:
# 34

# %% [markdown]
# # 9. Which Category Getting The Highest Average Rating?

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.groupby("Category")["Rating"].mean().sort_values(ascending=False)
# Out:
# Category
# 1.9                    19.000000
# EVENTS                  4.435556
# EDUCATION               4.389032
# ART_AND_DESIGN          4.358065
# BOOKS_AND_REFERENCE     4.346067
# PERSONALIZATION         4.335987
# PARENTING               4.300000
# GAME                    4.286326
# BEAUTY                  4.278571
# HEALTH_AND_FITNESS      4.277104
# SHOPPING                4.259664
# SOCIAL                  4.255598
# WEATHER                 4.244000
# SPORTS                  4.223511
# PRODUCTIVITY            4.211396
# HOUSE_AND_HOME          4.197368
# FAMILY                  4.192272
# PHOTOGRAPHY             4.192114
# AUTO_AND_VEHICLES       4.190411
# MEDICAL                 4.189143
# LIBRARIES_AND_DEMO      4.178462
# FOOD_AND_DRINK          4.166972
# COMMUNICATION           4.158537
# COMICS                  4.155172
# NEWS_AND_MAGAZINES      4.132189
# FINANCE                 4.131889
# ENTERTAINMENT           4.126174
# BUSINESS                4.121452
# ...

# %% [markdown]
# # 10. Find Total Number of App having 5 Star Rating

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df[df["Rating"]==5]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
len(df[df["Rating"]==5])
# Out:
# 10841

# %%
df[df["Rating"]==5].count()
# Out:
# App               10841
# Category          10841
# Rating            10841
# Reviews           10841
# Size              10841
# Installs          10841
# Type              10840
# Price             10841
# Content Rating    10840
# Genres            10841
# Last Updated      10841
# Current Ver       10833
# Android Ver       10838
# dtype: int64

# %% [markdown]
# # 11. Find Average Value of Reviews

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN       5
# 1                                Coloring book moana  ART_AND_DESIGN       5
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN       5
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN       5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN       5
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.dtypes
# Out:
# App               object
# Category          object
# Rating             int64
# Reviews           object
# Size              object
# Installs          object
# Type              object
# Price             object
# Content Rating    object
# Genres            object
# Last Updated      object
# Current Ver       object
# Android Ver       object
# dtype: object

# %%
df["Reviews"].astype(int)
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10841, dtype: int64

# %%
df[df.loc[:, "Reviews"].str.contains('3.0M')]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9       5    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df.loc[:, "Reviews"] = df.loc[:, "Reviews"].replace("3.0M", 3000000)

# %%
df["Reviews"] = df["Reviews"].astype('int')

# %%
df.dtypes
# Out:
# App               object
# Category          object
# Rating             int64
# Reviews            int64
# Size              object
# Installs          object
# Type              object
# Price             object
# Content Rating    object
# Genres            object
# Last Updated      object
# Current Ver       object
# Android Ver       object
# dtype: object

# %%
df["Reviews"].mean()
# Out:
# np.float64(444388.6535374965)

# %% [markdown]
# # 12. Find Total Number of Free and Paid Apps

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN       5
# 1                                Coloring book moana  ART_AND_DESIGN       5
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN       5
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN       5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN       5
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
free_vs_paid_apps = df["Type"].value_counts()

# %%
free_vs_paid_apps.plot(kind="bar")
# Out:
# <Axes: xlabel='Type'>

# %% [markdown]
# # 13.  Which App Has Maximum Reviews?

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN       5
# 1                                Coloring book moana  ART_AND_DESIGN       5
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN       5
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN       5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN       5
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df["Reviews"].max()
# Out:
# 78158306

# %%
df[df.loc[:, "Reviews"]==78158306]
# Out:
#            App Category  Rating   Reviews                Size        Installs  \
# 2544  Facebook   SOCIAL       5  78158306  Varies with device  1,000,000,000+
#
#       Type Price Content Rating  Genres    Last Updated         Current Ver  \
# 2544  Free     0           Teen  Social  August 3, 2018  Varies with device
#
#              Android Ver
# 2544  Varies with device

# %%
df[df["Reviews"] == df["Reviews"].max()] # To remember
# Out:
#            App Category  Rating   Reviews                Size        Installs  \
# 2544  Facebook   SOCIAL       5  78158306  Varies with device  1,000,000,000+
#
#       Type Price Content Rating  Genres    Last Updated         Current Ver  \
# 2544  Free     0           Teen  Social  August 3, 2018  Varies with device
#
#              Android Ver
# 2544  Varies with device

# %% [markdown]
# # 14. Display Top 5 Apps Having Highest Reviews

# %%
a = df["Reviews"].sort_values(ascending=False).head(5)

# %%
df.loc[a.index, :]
# Out:
#                      App       Category  Rating   Reviews                Size  \
# 2544            Facebook         SOCIAL       5  78158306  Varies with device
# 3943            Facebook         SOCIAL       5  78128208  Varies with device
# 381   WhatsApp Messenger  COMMUNICATION       5  69119316  Varies with device
# 336   WhatsApp Messenger  COMMUNICATION       5  69119316  Varies with device
# 3904  WhatsApp Messenger  COMMUNICATION       5  69109672  Varies with device
#
#             Installs  Type Price Content Rating         Genres  \
# 2544  1,000,000,000+  Free     0           Teen         Social
# 3943  1,000,000,000+  Free     0           Teen         Social
# 381   1,000,000,000+  Free     0       Everyone  Communication
# 336   1,000,000,000+  Free     0       Everyone  Communication
# 3904  1,000,000,000+  Free     0       Everyone  Communication
#
#         Last Updated         Current Ver         Android Ver
# ...

# %% [markdown]
# # 15. Find Average Rating of Free and Paid Apps

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN       5
# 1                                Coloring book moana  ART_AND_DESIGN       5
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN       5
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN       5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN       5
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.groupby("Type")["Rating"].mean()
# Out:
# Type
# 0       5.0
# Free    5.0
# Paid    5.0
# Name: Rating, dtype: float64

# %% [markdown]
# # 16. Display Top  5 Apps Having Maximum Installs

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN       5
# 1                                Coloring book moana  ART_AND_DESIGN       5
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN       5
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN       5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN       5
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.dtypes
# Out:
# App               object
# Category          object
# Rating             int64
# Reviews            int64
# Size              object
# Installs          object
# Type              object
# Price             object
# Content Rating    object
# Genres            object
# Last Updated      object
# Current Ver       object
# Android Ver       object
# dtype: object

# %%
df["Installs"]
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10841, dtype: object

# %%
df["Installs"] = df["Installs"].str.replace("+","")

# %%
df["Installs"] = df["Installs"].str.replace(",","")

# %%
df["Installs"]
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 10841, dtype: object

# %%
df[df.loc[:, "Installs"].str.contains("free",case=False)]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df.dtypes
# Out:
# App               object
# Category          object
# Rating             int64
# Reviews            int64
# Size              object
# Installs          object
# Type              object
# Price             object
# Content Rating    object
# Genres            object
# Last Updated      object
# Current Ver       object
# Android Ver       object
# dtype: object

# %%
df["Installs"] = df["Installs"].astype(int)

# %%
df.dtypes
# Out:
# App               object
# Category          object
# Rating             int64
# Reviews            int64
# Size              object
# Installs           int64
# Type              object
# Price             object
# Content Rating    object
# Genres            object
# Last Updated      object
# Current Ver       object
# Android Ver       object
# dtype: object

# %%
max_installs = df["Installs"].sort_values(ascending=False).head()

# %%
df.loc[max_installs.index, :]
# Out:
#                             App          Category  Rating   Reviews  \
# 2808              Google Photos       PHOTOGRAPHY       5  10858556
# 2853              Google Photos       PHOTOGRAPHY       5  10858538
# 3223  Maps - Navigate & Explore  TRAVEL_AND_LOCAL       5   9235373
# 3117  Maps - Navigate & Explore  TRAVEL_AND_LOCAL       5   9235155
# 3234                     Google             TOOLS       5   8033493
#
#                     Size    Installs  Type Price Content Rating  \
# 2808  Varies with device  1000000000  Free     0       Everyone
# 2853  Varies with device  1000000000  Free     0       Everyone
# 3223  Varies with device  1000000000  Free     0       Everyone
# 3117  Varies with device  1000000000  Free     0       Everyone
# 3234  Varies with device  1000000000  Free     0       Everyone
#
#               Genres    Last Updated         Current Ver         Android Ver
# 2808     Photography  August 6, 2018  Varies with device  Varies with device
# ...

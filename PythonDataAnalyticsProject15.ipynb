# %%
# Dataset Link - "https://www.kaggle.com/datasets/abdulrafay5/amazon-topselling-books"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\kavin\Downloads\archive (3)\Amazon-books.csv")

# %%
df
# Out:
#                                                   Title   Rank  Reviews  \
# 0                         Fourth Wing (The Empyrean, 1)      1      4.8
# 1     Atomic Habits: An Easy & Proven Way to Build G...      2      4.8
# 2                          Iron Flame (The Empyrean, 2)      3      4.7
# 3     Dinner Tonight: 100 Simple, Healthy Recipes fo...      4      4.1
# 4                Oath and Honor: A Memoir and a Warning      5      4.8
# ...                                                 ...    ...      ...
# 4841  4000 Word Search for Adults Large Print (200 T...   6201      4.4
# 4842                 Dracula (Deluxe Hardbound Edition)   6220      4.5
# 4843                       Goodnight Punpun, Vol. 6 (6)   6355      4.9
# 4844                Lucky Hit (Swift Hat-Trick Trilogy)   6910      4.1
# 4845  In the Fullness of Time: 32 Women on Life Afte...  15176      4.1
#
#       Review Count  Price                    Genre  \
# ...

# %%
# Checking for nulls

df.isnull().sum()
# Out:
# Title                 0
# Rank                  0
# Reviews               0
# Review Count          0
# Price                 0
# Genre                 0
# Manufacturer          0
# Brand              1702
# Author                0
# Number of Pages      71
# dtype: int64

# %%
df.isna().sum()
# Out:
# Title                 0
# Rank                  0
# Reviews               0
# Review Count          0
# Price                 0
# Genre                 0
# Manufacturer          0
# Brand              1702
# Author                0
# Number of Pages      71
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Title              0
# Rank               0
# Reviews            0
# Review Count       0
# Price              0
# Genre              0
# Manufacturer       0
# Brand              0
# Author             0
# Number of Pages    0
# dtype: int64

# %%
# Checking for duplicates

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3089 entries, 0 to 4845
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            3089 non-null   object
#  1   Rank             3089 non-null   int64
#  2   Reviews          3089 non-null   float64
#  3   Review Count     3089 non-null   int64
#  4   Price            3089 non-null   float64
#  5   Genre            3089 non-null   object
#  6   Manufacturer     3089 non-null   object
#  7   Brand            3089 non-null   object
#  8   Author           3089 non-null   object
#  9   Number of Pages  3089 non-null   float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 265.5+ KB

# %%
df.shape
# Out:
# (3089, 10)

# %%
df.sort_values("Review Count", ascending=False).head(10)
# Out:
#                                                   Title  Rank  Reviews  \
# 2665  Where the Crawdads Sing: Reese's Book Club (A ...  2767      4.7
# 115                        It Ends with Us: A Novel (1)   119      4.7
# 3797                           The Nightingale: A Novel  3947      4.7
# 118                            The Nightingale: A Novel   121      4.7
# 1445                                 The Silent Patient  1493      4.4
# 66                                   The Silent Patient    70      4.4
# 148                           Reminders of Him: A Novel   152      4.7
# 1535  The Midnight Library: A GMA Book Club Pick (A ...  1588      4.3
# 1327  Eleanor Oliphant Is Completely Fine: Reese's B...  1366      4.5
# 2119                     Beneath a Scarlet Sky: A Novel  2183      4.6
#
#       Review Count  Price          Genre           Manufacturer  \
# 2665        621499   5.19  Coming of Age     G.P. Putnam's Sons
# ...

# %%
df.hist(['Reviews', 'Price'])
plt.show()

# %%
x = df[df["Reviews"]==4.9]
x.head()
# Out:
#                                                 Title  Rank  Reviews  \
# 28  Baking Yesteryear: The Best Recipes from the 1...    30      4.9
# 29       Taylor Swift: A Little Golden Book Biography    31      4.9
# 87                        The Very Hungry Caterpillar    91      4.9
# 89  The Night Before Christmas Hardcover: The Clas...    93      4.9
# 99                            Berserk Deluxe Volume 1   102      4.9
#
#     Review Count  Price           Genre         Manufacturer  \
# 28          7063  17.66           Cakes                   DK
# 29          5363   4.78         Popular         Golden Books
# 87         73535   5.10  Bugs & Spiders  World of Eric Carle
# 89         11464   9.97       Christmas     Applesauce Press
# 99         15172  28.49         Fantasy     Dark Horse Manga
#
#                   Brand           Author  Number of Pages
# 28         SPA SERENITY  B. Dylan Hollis            256.0
# 29               LINGKU     Wendy Loggia             24.0
# ...

# %%
y = x.groupby("Title")["Review Count"].mean().sort_values(ascending=False).head(20)
plt.figure(figsize=(8,10))
sns.barplot(x =  y.values,y =  y.index)
plt.show()

# %%
# Relationship between number of pages and price

plt.figure(figsize= (12,6))
sns.scatterplot(data=df, x="Price",y="Number of Pages")
plt.show()

# %%
# Relationship between the price and review count

plt.figure(figsize=(12,6))
sns.scatterplot(data=df, x="Price", y="Review Count")
plt.show()

# %%
# Relationship between the review count vs rank


plt.figure(figsize=(12,6))
sns.scatterplot(data=df, x="Rank", y="Review Count")
plt.show()

# %%
df.head()
# Out:
#                                                 Title  Rank  Reviews  \
# 0                       Fourth Wing (The Empyrean, 1)     1      4.8
# 1   Atomic Habits: An Easy & Proven Way to Build G...     2      4.8
# 2                        Iron Flame (The Empyrean, 2)     3      4.7
# 7   Interesting Facts For Curious Minds: 1572 Rand...     8      4.5
# 10  A Court of Thorns and Roses (A Court of Thorns...    11      4.6
#
#     Review Count  Price                    Genre                Manufacturer  \
# 0         135916  18.69                  Fantasy  Entangled: Red Tower Books
# 1         120356  12.50  Personal Transformation                       Avery
# 2          79851  14.78                     Epic  Entangled: Red Tower Books
# 7           8072  12.48       Trivia & Fun Facts             Red Panda Press
# 10        157620   9.99                 Folklore       Bloomsbury Publishing
#
#                     Brand          Author  Number of Pages
# ...

# %%
# Price per page 

df["Price Per Page"] = df["Price"]/df["Number of Pages"]

# %%
df.head(1)
# Out:
#                            Title  Rank  Reviews  Review Count  Price    Genre  \
# 0  Fourth Wing (The Empyrean, 1)     1      4.8        135916  18.69  Fantasy
#
#                  Manufacturer      Brand          Author  Number of Pages  \
# 0  Entangled: Red Tower Books  Macmillan  Rebecca Yarros            528.0
#
#    Price Per Page
# 0        0.035398

# %%
# Price per one page across all books
df["Price Per Page"].mean()
# Out:
# np.float64(0.1091479729126556)

# %%
# Price per 10 pages across all books
df["Price Per Page"].mean()* 10
# Out:
# np.float64(1.091479729126556)

# %%
# Best Selling authors

df["Total Revenue"] = df["Price"] * df["Review Count"]
author_sales = df.groupby("Author")["Total Revenue"].sum().head(10)

top_10_authors = author_sales.sort_values(ascending=False).head(10)

# %%
sns.barplot(data=top_10_authors)
plt.xticks(rotation=75)
plt.show()

# %%
top_10_authors
# Out:
# Author
# A. R. Torre       339122.16
# Aaron Horschig    158464.54
# Aaron Blabey      152785.74
# AAWS AAWS         111058.50
# A. J. Baime        94611.34
# AB Mojang          90005.85
# A. Helwa           88800.66
# Aaria Baid         44244.48
# Aaron Johnson      16190.01
# A. Grambs            263.78
# Name: Total Revenue, dtype: float64

# %%
# Finding the author with maximum reviews

df.groupby("Author")["Review Count"].sum().sort_values(ascending=False).head(1)
# Out:
# Author
# Sarah J. Maas    2451630
# Name: Review Count, dtype: int64

# %%
df.groupby("Author")["Review Count"].sum().sort_values(ascending=False).head(1).index[0]
# Out:
# 'Sarah J. Maas'

# %%
author_reviews = df.groupby('Author')['Review Count'].sum()

max_reviews_author = author_reviews.idxmax() # Gives the name
max_reviews_value = author_reviews.max() # Gives the number

print(f"Author with max reviews: {max_reviews_author} with {max_reviews_value} reviews ")
# Out:
# Author with max reviews: Sarah J. Maas with 2451630 reviews

# %%
# Plotting the authors with max reviews

top_10_authors_with_max_reviews = author_reviews.sort_values(ascending=False).head(10)

sns.barplot(data=top_10_authors_with_max_reviews)
plt.title("Top 10 Authors with Most Reviews")
plt.xticks(rotation=75)
plt.show()

# %%
# Visualizing the frequencies of authors in the dataset

# Combine all author names into one big text string
text = ' '.join(df['Author'])

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the generated image:
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide axes
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 7
#       4 text = ' '.join(df['Author'])
#       6 # Generate word cloud
# ----> 7 wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
#       9 # Display the generated image:
#      10 plt.figure(figsize=(10, 5))
#
# NameError: name 'WordCloud' is not defined

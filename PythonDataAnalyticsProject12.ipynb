# %%
# Dataset Link - https://www.kaggle.com/datasets/heesoo37/120-years-of-olympic-history-athletes-and-results

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\kavin\Downloads\archive\athlete_events.csv")

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# # Display the top 5 rows

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# # Display last 5 rows

# %%
df.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# 271112  Ski Jumping Men's Large Hill, Individual   NaN
# 271113        Ski Jumping Men's Large Hill, Team   NaN
# 271114                      Bobsleigh Men's Four   NaN
# 271115                      Bobsleigh Men's Four   NaN

# %% [markdown]
# # Printing 5 random rows

# %%
df.sample(5)
# Out:
#            ID                         Name Sex   Age  Height  Weight  \
# 7692     4280   Nikolaos "Nikos" Angelidis   M  23.0   183.0    79.0
# 17478    9315                    Carol Bed   M  21.0     NaN     NaN
# 113075  57283  Arja Leena Kantola (-Klemz)   F  22.0   167.0    54.0
# 54257   27838                 Maria Despas   F  30.0   165.0    61.0
# 55675   28530       Damon Laurance Diletti   M  21.0   178.0    86.0
#
#              Team  NOC        Games  Year  Season       City  \
# 7692       Greece  GRE  2000 Summer  2000  Summer     Sydney
# 17478     Romania  ROU  1952 Summer  1952  Summer   Helsinki
# 113075    Finland  FIN  1972 Winter  1972  Winter    Sapporo
# 54257   Australia  AUS  1998 Winter  1998  Winter     Nagano
# 55675   Australia  AUS  1992 Summer  1992  Summer  Barcelona
#
#                    Sport                               Event   Medal
# 7692             Cycling                Cycling Men's Sprint     NaN
# 17478         Gymnastics    Gymnastics Men's Team All-Around     NaN
# 113075     Speed Skating  Speed Skating Women's 1,000 metres     NaN
# 54257   Freestyle Skiing     Freestyle Skiing Women's Moguls     NaN
# 55675             Hockey                 Hockey Men's Hockey  Silver

# %% [markdown]
# # Shape of the dataset

# %%
df.shape
# Out:
# (271116, 15)

# %% [markdown]
# # Checking for missing values

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %% [markdown]
# # Replacing the missing values with the mean of each column. No need for the medals because it reprents no medals.

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())
df["Height"] = df["Height"].fillna(df["Height"].mean())
df["Weight"] = df["Weight"].fillna(df["Weight"].mean())

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age            0
# Height         0
# Weight         0
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %% [markdown]
# # Dataset info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     271116 non-null  float64
#  4   Height  271116 non-null  float64
#  5   Weight  271116 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %% [markdown]
# # Statistics of the dataset

# %%
df.describe()
# Out:
#                   ID            Age        Height         Weight  \
# count  271116.000000  271116.000000  271116.00000  271116.000000
# mean    68248.954396      25.556898     175.33897      70.702393
# std     39022.286345       6.280857       9.27810      12.574690
# min         1.000000      10.000000     127.00000      25.000000
# 25%     34643.000000      22.000000     170.00000      63.000000
# 50%     68205.000000      25.000000     175.33897      70.702393
# 75%    102097.250000      28.000000     180.00000      75.000000
# max    135571.000000      97.000000     226.00000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# # Checking for duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(1385)

# %% [markdown]
# # Drop the duplicates

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Correlation analysis - Helps us understand how different features are connected to each other

# %%
numerical_data = df.select_dtypes(include='number')
numerical_data.corr()
# Out:
#               ID       Age    Height    Weight      Year
# ID      1.000000 -0.002825 -0.009791 -0.008059  0.011381
# Age    -0.002825  1.000000  0.111115  0.168071 -0.088250
# Height -0.009791  0.111115  1.000000  0.786635  0.030126
# Weight -0.008059  0.168071  0.786635  1.000000  0.011598
# Year    0.011381 -0.088250  0.030126  0.011598  1.000000

# %%
sns.heatmap(numerical_data.corr()) # Shows the Pearson Correlation Coefficient between the different features
# # Values between -1 and 1. 0 - no correlation. 1 - perfect correlation. Light colors indicate higher correlations.
# Out:
# <Axes: >

# %% [markdown]
# # How to search for a value if you don't know the column name in which it is in

# %%
mask = df.apply(lambda col: col.astype(str).str.contains("jiang", na=False))
matches = df[mask.any(axis=1)]
matches
# Out:
#             ID             Name Sex   Age     Height     Weight       Team  \
# 0            1        A Dijiang   M  24.0  180.00000  80.000000      China
# 6427      3605      An Weijiang   M  22.0  178.00000  72.000000      China
# 6428      3605      An Weijiang   M  22.0  178.00000  72.000000      China
# 86663    43952   Guo Chengjiang   M  24.0  175.33897  70.702393      China
# 100065   50636    Huang Qijiang   M  19.0  182.00000  72.000000      China
# 100137   50662   Huang Yaojiang   M  22.0  189.00000  80.000000      China
# 100138   50662   Huang Yaojiang   M  22.0  189.00000  80.000000      China
# 100139   50662   Huang Yaojiang   M  26.0  189.00000  80.000000      China
# 137920   69315    Li Chengjiang   M  22.0  170.00000  61.000000      China
# 137921   69315    Li Chengjiang   M  26.0  170.00000  61.000000      China
# 137938   69323     Li Chunjiang   M  29.0  190.00000  85.000000      China
# 232175  116477    Sun Longjiang   M  17.0  194.00000  85.000000      China
# 238794  119716  Thio Him Tjiang   M  27.0  175.33897  70.702393  Indonesia
# 263466  131834     Wu Xingjiang   F  27.0  174.00000  70.000000      China
#
#         NOC        Games  Year  Season            City           Sport  \
# 0       CHN  1992 Summer  1992  Summer       Barcelona      Basketball
# 6427    CHN  2006 Winter  2006  Winter          Torino   Speed Skating
# 6428    CHN  2006 Winter  2006  Winter          Torino   Speed Skating
# 86663   CHN  1980 Winter  1980  Winter     Lake Placid   Speed Skating
# 100065  CHN  1988 Summer  1988  Summer           Seoul      Water Polo
# 100137  CHN  2004 Summer  2004  Summer          Athina         Fencing
# 100138  CHN  2004 Summer  2004  Summer          Athina         Fencing
# 100139  CHN  2008 Summer  2008  Summer         Beijing         Fencing
# 137920  CHN  2002 Winter  2002  Winter  Salt Lake City  Figure Skating
# 137921  CHN  2006 Winter  2006  Winter          Torino  Figure Skating
# 137938  CHN  1992 Summer  1992  Summer       Barcelona      Basketball
# 232175  CHN  2010 Winter  2010  Winter       Vancouver   Speed Skating
# 238794  INA  1956 Summer  1956  Summer       Melbourne        Football
# 263466  CHN  1984 Summer  1984  Summer     Los Angeles        Handball
#
#                                    Event   Medal
# 0            Basketball Men's Basketball     NaN
# 6427      Speed Skating Men's 500 metres     NaN
# 6428    Speed Skating Men's 1,000 metres     NaN
# 86663   Speed Skating Men's 1,500 metres     NaN
# 100065       Water Polo Men's Water Polo     NaN
# 100137   Fencing Men's Sabre, Individual     NaN
# 100138         Fencing Men's Sabre, Team     NaN
# 100139         Fencing Men's Sabre, Team     NaN
# 137920      Figure Skating Men's Singles     NaN
# 137921      Figure Skating Men's Singles     NaN
# 137938       Basketball Men's Basketball     NaN
# 232175  Speed Skating Men's 1,500 metres     NaN
# 238794           Football Men's Football     NaN
# 263466         Handball Women's Handball  Bronze

# %% [markdown]
# # Univariate analysis

# %% [markdown]
# ## Categorical data

# %%
df.head()
# Out:
#    ID                      Name Sex   Age     Height     Weight  \
# 0   1                 A Dijiang   M  24.0  180.00000  80.000000
# 1   2                  A Lamusi   M  23.0  170.00000  60.000000
# 2   3       Gunnar Nielsen Aaby   M  24.0  175.33897  70.702393
# 3   4      Edgar Lindenau Aabye   M  34.0  175.33897  70.702393
# 4   5  Christine Jacoba Aaftink   F  21.0  185.00000  82.000000
#
#              Team  NOC        Games  Year  Season       City          Sport  \
# 0           China  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1           China  CHN  2012 Summer  2012  Summer     London           Judo
# 2         Denmark  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4     Netherlands  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# ### Distribution of Athletes by Gender (Sex)

# %%
df["Sex"].value_counts()
# Out:
# Sex
# M    195353
# F     74378
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x="Sex")
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
m_vs_f = df["Sex"].value_counts().reset_index()
m_vs_f
# Out:
#   Sex   count
# 0   M  195353
# 1   F   74378

# %%
sns.barplot(data=m_vs_f, x="Sex", y="count")
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
m_vs_f = df["Sex"].value_counts()
m_vs_f
# Out:
# Sex
# M    195353
# F     74378
# Name: count, dtype: int64

# %%
m_vs_f.index
# Out:
# Index(['M', 'F'], dtype='object', name='Sex')

# %%
m_vs_f.values
# Out:
# array([195353,  74378])

# %%
sns.barplot(x=m_vs_f.index, y=m_vs_f.values) # Here we don't need to add the data=m_vs_f part. Wow!
# If it's a dataframe, we need to mention data=df, if they are a series, we can just name the series. 

plt.title("Gender distribution in the olympics")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Most popular sports based on athlete participation

# %%
df.head(1)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
#
#    Season       City       Sport                        Event Medal
# 0  Summer  Barcelona  Basketball  Basketball Men's Basketball   NaN

# %%
df["Sport"].value_counts().sort_values(ascending=False).head(10)
# Out:
# Sport
# Athletics               38624
# Gymnastics              26707
# Swimming                23195
# Shooting                11448
# Cycling                 10827
# Fencing                 10735
# Rowing                  10595
# Cross Country Skiing     9133
# Alpine Skiing            8829
# Wrestling                7154
# Name: count, dtype: int64

# %%
most_pop_sports = df["Sport"].value_counts().sort_values(ascending=False).head(10)

# %%
sns.barplot(x=most_pop_sports.index, y = most_pop_sports.values)
plt.xticks(rotation=75)
plt.xlabel("Sport")
plt.ylabel("Num. of Athletes")
plt.tight_layout()
plt.show()

# %%
df["Sport"].value_counts().sort_values(ascending=False).head(10).plot(kind="pie", autopct="%.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["Sport"].value_counts().idxmax() # Returns the label of the first maximum value
# Out:
# 'Athletics'

# %%
help(pd.Series.idxmax)
# Out:
# Help on function idxmax in module pandas.core.series:
#
# idxmax(self, axis: 'Axis' = 0, skipna: 'bool' = True, *args, **kwargs) -> 'Hashable'
#     Return the row label of the maximum value.
#
#     If multiple values equal the maximum, the first row label with that
#     value is returned.
#
#     Parameters
#     ----------
#     axis : {0 or 'index'}
#         Unused. Parameter needed for compatibility with DataFrame.
#     skipna : bool, default True
#         Exclude NA/null values. If the entire Series is NA, the result
#         will be NA.
#     *args, **kwargs
#         Additional arguments and keywords have no effect but might be
#         accepted for compatibility with NumPy.
#
#     Returns
#     -------
#     Index
#         Label of the maximum value.
#
#     Raises
#     ------
#     ValueError
#         If the Series is empty.
#
#     See Also
#     --------
#     numpy.argmax : Return indices of the maximum values
#         along the given axis.
#     DataFrame.idxmax : Return index of first occurrence of maximum
#         over requested axis.
#     Series.idxmin : Return index *label* of the first occurrence
#         of minimum of values.
#
#     Notes
#     -----
#     This method is the Series version of ``ndarray.argmax``. This method
#     returns the label of the maximum, while ``ndarray.argmax`` returns
#     the position. To get the position, use ``series.values.argmax()``.
#
#     Examples
#     --------
#     >>> s = pd.Series(data=[1, None, 4, 3, 4],
#     ...               index=['A', 'B', 'C', 'D', 'E'])
#     >>> s
#     A    1.0
#     B    NaN
#     C    4.0
#     D    3.0
#     E    4.0
#     dtype: float64
#
#     >>> s.idxmax()
#     'C'
#
#     If `skipna` is False and there is an NA value in the data,
#     the function returns ``nan``.
#
#     >>> s.idxmax(skipna=False)
#     nan

# %%
pd.Series.idxmax?
# Out:
# Signature:
# pd.Series.idxmax(
#     self,
#     axis: 'Axis' = 0,
#     skipna: 'bool' = True,
#     *args,
#     **kwargs,
# ) -> 'Hashable'
# Docstring:
# Return the row label of the maximum value.
#
# If multiple values equal the maximum, the first row label with that
# value is returned.
#
# Parameters
# ----------
# axis : {0 or 'index'}
#     Unused. Parameter needed for compatibility with DataFrame.
# skipna : bool, default True
#     Exclude NA/null values. If the entire Series is NA, the result
#     will be NA.
# *args, **kwargs
#     Additional arguments and keywords have no effect but might be
#     accepted for compatibility with NumPy.
#
# Returns
# -------
# Index
#     Label of the maximum value.
#
# Raises
# ------
# ValueError
#     If the Series is empty.
#
# See Also
# --------
# numpy.argmax : Return indices of the maximum values
#     along the given axis.
# DataFrame.idxmax : Return index of first occurrence of maximum
#     over requested axis.
# Series.idxmin : Return index *label* of the first occurrence
#     of minimum of values.
#
# Notes
# -----
# This method is the Series version of ``ndarray.argmax``. This method
# returns the label of the maximum, while ``ndarray.argmax`` returns
# the position. To get the position, use ``series.values.argmax()``.
#
# Examples
# --------
# >>> s = pd.Series(data=[1, None, 4, 3, 4],
# ...               index=['A', 'B', 'C', 'D', 'E'])
# >>> s
# A    1.0
# B    NaN
# C    4.0
# D    3.0
# E    4.0
# dtype: float64
#
# >>> s.idxmax()
# 'C'
#
# If `skipna` is False and there is an NA value in the data,
# the function returns ``nan``.
#
# >>> s.idxmax(skipna=False)
# nan
# File:      c:\users\kavin\anaconda3\lib\site-packages\pandas\core\series.py
# Type:      function

# %% [markdown]
# ## Numerical Data

# %%
df.head()
# Out:
#    ID                      Name Sex   Age     Height     Weight  \
# 0   1                 A Dijiang   M  24.0  180.00000  80.000000
# 1   2                  A Lamusi   M  23.0  170.00000  60.000000
# 2   3       Gunnar Nielsen Aaby   M  24.0  175.33897  70.702393
# 3   4      Edgar Lindenau Aabye   M  34.0  175.33897  70.702393
# 4   5  Christine Jacoba Aaftink   F  21.0  185.00000  82.000000
#
#              Team  NOC        Games  Year  Season       City          Sport  \
# 0           China  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1           China  CHN  2012 Summer  2012  Summer     London           Judo
# 2         Denmark  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4     Netherlands  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# ## Distribution of age

# %%
df["Age"].hist(bins=50)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x="Age", bins=20, kde=True)
plt.xlabel("Age")
plt.tight_layout()
plt.show()

# %%
sns.boxplot(data=df, x="Age")
# Out:
# <Axes: xlabel='Age'>

# %%
df["Age"].max()
# Out:
# 97.0

# %%
df["Age"].min()
# Out:
# 10.0

# %%
df["Age"].mean()
# Out:
# np.float64(25.458302932173996)

# %%
df["Age"].skew() 

#  0 - A perfectly symmetrical distrubution. (Normal distribution). 
# Skew > 0 - Positively skewed. 
# 0 > Skew - Negatively skewed. Left tail is longer than the right.
# Out:
# np.float64(1.5877141959478527)

# %% [markdown]
# # Bivariate Analysis (2 columns at a time) and Multivariate Analysis (more than 2 columns/ variables)

# %% [markdown]
# ## 1. Numerical-Numerical Relationships

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
sns.scatterplot(data=df, x="Age", y="Height")
plt.show()

# %%
sns.scatterplot(data=df, x="Age", y="Height",hue="Sex")
plt.show()

# %% [markdown]
# ## 2. Numerical-Categorical Relationships (Age distribution by medal type)

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
sns.barplot(data=df, x="Medal", y="Age", hue="Sex").legend(bbox_to_anchor=(1, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
sns.boxplot(data=df, x="Age", y="Medal", hue="Sex")
plt.show()

# %% [markdown]
# ## 2. Numerical-Categorical Relationships (Age distribution by medal type)

# %% [markdown]
# # ## How many Gold, Silver, and Bronze medals have been awarded to male and female athletes?

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
df.groupby("Sex")["Medal"].count()
# Out:
# Sex
# F    11253
# M    28519
# Name: Medal, dtype: int64

# %%
a = df["Medal"].unique()
a
# Out:
# array([nan, 'Gold', 'Bronze', 'Silver'], dtype=object)

# %%
wow = pd.crosstab(df["Medal"], df["Sex"])
wow
# Out:
# Sex        F     M
# Medal
# Bronze  3771  9524
# Gold    3747  9622
# Silver  3735  9373

# %%
df.pivot_table( index="Medal", columns="Sex", aggfunc="size")
# Out:
# Sex        F     M
# Medal
# Bronze  3771  9524
# Gold    3747  9622
# Silver  3735  9373

# %%
df.pivot_table(index="Medal", columns="Sex", aggfunc="count")
# Out:
#          Age        City       Event       Games       Height        ...  \
# Sex        F     M     F     M     F     M     F     M      F     M  ...
# Medal                                                                ...
# Bronze  3771  9524  3771  9524  3771  9524  3771  9524   3771  9524  ...
# Gold    3747  9622  3747  9622  3747  9622  3747  9622   3747  9622  ...
# Silver  3735  9373  3735  9373  3735  9373  3735  9373   3735  9373  ...
#
#        Season       Sport        Team       Weight        Year
# Sex         F     M     F     M     F     M      F     M     F     M
# Medal
# Bronze   3771  9524  3771  9524  3771  9524   3771  9524  3771  9524
# Gold     3747  9622  3747  9622  3747  9622   3747  9622  3747  9622
# Silver   3735  9373  3735  9373  3735  9373   3735  9373  3735  9373
#
# [3 rows x 26 columns]

# %%
sns.heatmap(pd.crosstab(df["Sex"],df["Medal"]))
# Out:
# <Axes: xlabel='Medal', ylabel='Sex'>

# %% [markdown]
# ## 2. Numerical-Numerical Relationships

# %% [markdown]
# ### Medal performance for a specific country per year

# %%
df.head(1)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
#
#    Season       City       Sport                        Event Medal
# 0  Summer  Barcelona  Basketball  Basketball Men's Basketball   NaN

# %%
df["Team"]
# Out:
# 0                  China
# 1                  China
# 2                Denmark
# 3         Denmark/Sweden
# 4            Netherlands
#                ...
# 271111          Poland-1
# 271112            Poland
# 271113            Poland
# 271114            Poland
# 271115            Poland
# Name: Team, Length: 269731, dtype: object

# %%
df[df["Team"]=="Sri Lanka"]
# Out:
#             ID                             Name Sex   Age     Height  \
# 749        429                 Ruwani Abeymanne   F  30.0  160.00000
# 750        429                 Ruwani Abeymanne   F  30.0  160.00000
# 751        430        Matthew Duncan Abeysinghe   M  20.0  180.00000
# 6059      3410      Vijitha Padmini Amerasekera   F  30.0  170.00000
# 22515    11869                 Janaka Biyanwila   M  31.0  175.33897
# ...        ...                              ...  ..   ...        ...
# 260452  130344      Phjilip Revatha Wijewardene   M  44.0  180.00000
# 260453  130345       Ansela Marlen Wijewickrema   M  20.0  175.33897
# 261154  130693  Malcolm Anthony "Tony" Williams   M  21.0  175.00000
# 261648  130923        Wickramesinghe Wimaladasa   M  28.0  177.00000
# 261649  130924         Ranga Kumara Wimalawansa   M  20.0  182.00000
#
#            Weight       Team  NOC        Games  Year  Season            City  \
# 749     53.000000  Sri Lanka  SRI  2000 Summer  2000  Summer          Sydney
# 750     53.000000  Sri Lanka  SRI  2000 Summer  2000  Summer          Sydney
# 751     74.000000  Sri Lanka  SRI  2016 Summer  2016  Summer  Rio de Janeiro
# 6059    64.000000  Sri Lanka  SRI  1992 Summer  1992  Summer       Barcelona
# 22515   70.702393  Sri Lanka  SRI  1996 Summer  1996  Summer         Atlanta
# ...           ...        ...  ...          ...   ...     ...             ...
# 260452  86.000000  Sri Lanka  SRI  1968 Summer  1968  Summer     Mexico City
# 260453  51.000000  Sri Lanka  SRI  1992 Summer  1992  Summer       Barcelona
# 261154  61.000000  Sri Lanka  SRI  1960 Summer  1960  Summer            Roma
# 261648  62.000000  Sri Lanka  SRI  1972 Summer  1972  Summer          Munich
# 261649  70.000000  Sri Lanka  SRI  2000 Summer  2000  Summer          Sydney
#
#                 Sport                                        Event Medal
# 749          Shooting       Shooting Women's Air Pistol, 10 metres   NaN
# 750          Shooting  Shooting Women's Sporting Pistol, 25 metres   NaN
# 751          Swimming          Swimming Men's 100 metres Freestyle   NaN
# 6059        Athletics              Athletics Women's Javelin Throw   NaN
# 22515          Diving                     Diving Men's Springboard   NaN
# ...               ...                                          ...   ...
# 260452        Sailing              Sailing Mixed One Person Dinghy   NaN
# 260453  Weightlifting                Weightlifting Men's Flyweight   NaN
# 261154       Swimming       Swimming Men's 200 metres Breaststroke   NaN
# 261648      Athletics                   Athletics Men's 400 metres   NaN
# 261649      Athletics         Athletics Men's 4 x 400 metres Relay   NaN
#
# [146 rows x 15 columns]

# %%
sri_lankan_medal = df[df["Team"]=="Sri Lanka"].groupby("Year")["Medal"].count()

# %%
sns.lineplot(x=sri_lankan_medal.index, y=sri_lankan_medal.values)
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ## 2. Numerical-Categorical Relationships

# %% [markdown]
# # Top 10 athletes by the number of medals won

# %%
df.head(1)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
#
#    Season       City       Sport                        Event Medal
# 0  Summer  Barcelona  Basketball  Basketball Men's Basketball   NaN

# %%
df.groupby("Name")["Medal"].count().sort_values(ascending=False).head(10)
# Out:
# Name
# Michael Fred Phelps, II               28
# Larysa Semenivna Latynina (Diriy-)    18
# Nikolay Yefimovich Andrianov          15
# Edoardo Mangiarotti                   13
# Takashi Ono                           13
# Borys Anfiyanovych Shakhlin           13
# Ole Einar Bjrndalen                   13
# Paavo Johannes Nurmi                  12
# Sawao Kato                            12
# Ryan Steven Lochte                    12
# Name: Medal, dtype: int64

# %%
top_athletes = df.groupby("Name")["Medal"].count().sort_values(ascending=False).head(10)

# %%
sns.barplot(y=top_athletes.index,x=top_athletes.values)
plt.show()

# %% [markdown]
# ## The count of medals won in each host city

# %%
df.head(1)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
#
#    Season       City       Sport                        Event Medal
# 0  Summer  Barcelona  Basketball  Basketball Men's Basketball   NaN

# %%
df.groupby(["City", "Medal"]).size().unstack()
# Out:
# Medal                   Bronze  Gold  Silver
# City
# Albertville                106   104     108
# Amsterdam                  250   245     239
# Antwerpen                  367   493     448
# Athina                     860   883     859
# Atlanta                    629   608     605
# Barcelona                  604   559     549
# Beijing                    710   671     667
# Berlin                     295   312     310
# Calgary                     88    87      88
# Chamonix                    37    55      38
# Cortina d'Ampezzo           50    51      49
# Garmisch-Partenkirchen      35    36      37
# Grenoble                    63    66      70
# Helsinki                   300   306     291
# Innsbruck                  128   131     138
# Lake Placid                101   104     105
# Lillehammer                112   110     109
# London                    1214  1215    1195
# Los Angeles                706   726     691
# Melbourne                  286   290     281
# Mexico City                358   359     340
# Montreal                   448   438     434
# Moskva                     469   457     458
# Munich                     419   404     392
# Nagano                     150   145     145
# Oslo                        47    45      44
# Paris                      449   475     501
# Rio de Janeiro             703   665     655
# Roma                       308   309     294
# Salt Lake City             159   162     157
# Sankt Moritz                77    71      76
# Sapporo                     66    70      63
# Sarajevo                    74    74      74
# Seoul                      549   520     513
# Sochi                      198   202     197
# Squaw Valley                49    50      48
# St. Louis                  150   173     163
# Stockholm                  312   338     327
# Sydney                     680   663     661
# Tokyo                      343   347     339
# Torino                     175   176     175
# Vancouver                  171   174     175

# %% [markdown]
# ## Sort the medal counts per city based on total number of medals (Bronze, Silver, Gold)

# %%
medal_count = df.groupby(["City", "Medal"]).size().unstack()

# %%
medal_count["Total"] = medal_count[["Bronze", "Silver", "Gold"]].sum(axis=1)

# %%
medal_count
# Out:
# Medal                   Bronze  Gold  Silver  Total
# City
# Albertville                106   104     108    318
# Amsterdam                  250   245     239    734
# Antwerpen                  367   493     448   1308
# Athina                     860   883     859   2602
# Atlanta                    629   608     605   1842
# Barcelona                  604   559     549   1712
# Beijing                    710   671     667   2048
# Berlin                     295   312     310    917
# Calgary                     88    87      88    263
# Chamonix                    37    55      38    130
# Cortina d'Ampezzo           50    51      49    150
# Garmisch-Partenkirchen      35    36      37    108
# Grenoble                    63    66      70    199
# Helsinki                   300   306     291    897
# Innsbruck                  128   131     138    397
# Lake Placid                101   104     105    310
# Lillehammer                112   110     109    331
# London                    1214  1215    1195   3624
# Los Angeles                706   726     691   2123
# Melbourne                  286   290     281    857
# Mexico City                358   359     340   1057
# Montreal                   448   438     434   1320
# Moskva                     469   457     458   1384
# Munich                     419   404     392   1215
# Nagano                     150   145     145    440
# Oslo                        47    45      44    136
# Paris                      449   475     501   1425
# Rio de Janeiro             703   665     655   2023
# Roma                       308   309     294    911
# Salt Lake City             159   162     157    478
# Sankt Moritz                77    71      76    224
# Sapporo                     66    70      63    199
# Sarajevo                    74    74      74    222
# Seoul                      549   520     513   1582
# Sochi                      198   202     197    597
# Squaw Valley                49    50      48    147
# St. Louis                  150   173     163    486
# Stockholm                  312   338     327    977
# Sydney                     680   663     661   2004
# Tokyo                      343   347     339   1029
# Torino                     175   176     175    526
# Vancouver                  171   174     175    520

# %%
medal_count.sort_values(by="Total", ascending=False)
# Out:
# Medal                   Bronze  Gold  Silver  Total
# City
# London                    1214  1215    1195   3624
# Athina                     860   883     859   2602
# Los Angeles                706   726     691   2123
# Beijing                    710   671     667   2048
# Rio de Janeiro             703   665     655   2023
# Sydney                     680   663     661   2004
# Atlanta                    629   608     605   1842
# Barcelona                  604   559     549   1712
# Seoul                      549   520     513   1582
# Paris                      449   475     501   1425
# Moskva                     469   457     458   1384
# Montreal                   448   438     434   1320
# Antwerpen                  367   493     448   1308
# Munich                     419   404     392   1215
# Mexico City                358   359     340   1057
# Tokyo                      343   347     339   1029
# Stockholm                  312   338     327    977
# Berlin                     295   312     310    917
# Roma                       308   309     294    911
# Helsinki                   300   306     291    897
# Melbourne                  286   290     281    857
# Amsterdam                  250   245     239    734
# Sochi                      198   202     197    597
# Torino                     175   176     175    526
# Vancouver                  171   174     175    520
# St. Louis                  150   173     163    486
# Salt Lake City             159   162     157    478
# Nagano                     150   145     145    440
# Innsbruck                  128   131     138    397
# Lillehammer                112   110     109    331
# Albertville                106   104     108    318
# Lake Placid                101   104     105    310
# Calgary                     88    87      88    263
# Sankt Moritz                77    71      76    224
# Sarajevo                    74    74      74    222
# Sapporo                     66    70      63    199
# Grenoble                    63    66      70    199
# Cortina d'Ampezzo           50    51      49    150
# Squaw Valley                49    50      48    147
# Oslo                        47    45      44    136
# Chamonix                    37    55      38    130
# Garmisch-Partenkirchen      35    36      37    108

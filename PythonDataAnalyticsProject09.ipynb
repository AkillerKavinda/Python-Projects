# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\kavin\Downloads\archive\top-5000-youtube-channels.csv")

# %%
df.head()
# Out:
#   Rank Grade                Channel name Video Uploads Subscribers  \
# 0  1st  A++                       Zee TV         82757    18752951
# 1  2nd  A++                     T-Series         12661    61196302
# 2  3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3  4th  A++                    SET India         27323    31180559
# 4  5th  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %% [markdown]
# # 1. Display All Rows Except the Last 5 rows Using Head Method

# %%
df.head(-5)
# Out:
#          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# ...       ...   ...                               ...           ...
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel           208
# 4991  4,992nd   B+               Toys to Learn Colors            11
# 4992  4,993rd   B+                              КАZКА            25
# 4993  4,994th   B+   United CUBE (CUBE Entertainment…          1055
# 4994  4,995th   B+                      Wings Marathi          1735
#
#      Subscribers  Video views
# 0       18752951  20869786591
# 1       61196302  47548839843
# 2       19238251   9793305082
# ...

# %% [markdown]
# # 2. Display All Rows Except the First 5 Rows Using Tail Method

# %%
df.tail(-5)
# Out:
#          Rank Grade           Channel name Video Uploads Subscribers  \
# 5         6th  A++              Movieclips         30243    17149705
# 6         7th  A++              netd müzik          8500    11373567
# 7         8th  A++   ABS-CBN Entertainment        100147    12149206
# 8         9th  A++         Ryan ToysReview          1140    16082927
# 9        10th  A++             Zee Marathi         74607     2841811
# ...       ...   ...                    ...           ...         ...
# 4995  4,996th   B+          Uras Benlioğlu           706     2072942
# 4996  4,997th   B+       HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+             Mastersaint           110     3265735
# 4998  4,999th   B+          Bruce McIntosh          3475       32990
# 4999  5,000th   B+               SehatAQUA           254       21172
#
#       Video views
# 5     16618094724
# 6     23898730764
# 7     17202609850
# 8     24518098041
# 9      2591830307
# ...           ...
# ...

# %% [markdown]
# # 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
df.shape
# Out:
# (5000, 6)

# %%
print("Number of rows : ", df.shape[0])
print("Number of columns : ", df.shape[1])
# Out:
# Number of rows :  5000
# Number of columns :  6

# %% [markdown]
# # 4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %% [markdown]
# # 5. Get Overall Statistics About The Dataframe

# %%
pd.options.display.float_format = '{:.2f}'.format # Converting the exponential format to decimal format

# %%
df.describe()
# Out:
#          Video views
# count        5000.00
# mean   1071449400.15
# std    2003843972.12
# min            75.00
# 25%     186232945.75
# 50%     482054780.00
# 75%    1124367826.75
# max   47548839843.00

# %%
df.describe(include='all')
# Out:
#            Rank Grade           Channel name Video Uploads Subscribers  \
# count      5000  5000                   5000          5000        5000
# unique     5000     6                   4993          2286        4612
# top     5,000th   B+   Learn Colors For Kids            26         --
# freq          1  2956                      2            17         387
# mean        NaN   NaN                    NaN           NaN         NaN
# std         NaN   NaN                    NaN           NaN         NaN
# min         NaN   NaN                    NaN           NaN         NaN
# 25%         NaN   NaN                    NaN           NaN         NaN
# 50%         NaN   NaN                    NaN           NaN         NaN
# 75%         NaN   NaN                    NaN           NaN         NaN
# max         NaN   NaN                    NaN           NaN         NaN
#
#           Video views
# count         5000.00
# unique            NaN
# top               NaN
# freq              NaN
# ...

# %% [markdown]
# # 6. Data Cleaning  (Replace '--'  to NaN)

# %%
df.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
df[(df == "--").any(axis=1)]
# Out:
#          Rank Grade                  Channel name Video Uploads Subscribers  \
# 267     268th                    MidnightXChannel            --         --
# 517     518th                      Dusama Pets TV            --         --
# 2323  2,324th                              Random            --       12275
# 3072  3,073rd        Boram Tube Toy Shcool [보람튜브…            --      726527
# 3247  3,248th                       atheer sultan            --         --
# 4898  4,899th                        ExzoticSlice            --       99785
#
#       Video views
# 267     190256974
# 517      91601494
# 2323     17897584
# 3072    205555289
# 3247     79663674
# 4898      9745292

# %%
import numpy as np
df = df.replace("--", np.nan, regex=True)

# %%
df.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
df[(df == "--").any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Rank, Grade, Channel name, Video Uploads, Subscribers, Video views]
# Index: []

# %% [markdown]
# # 7. Check Null Values In The Dataset

# %%
df.isnull().sum()
# Out:
# Rank               0
# Grade              0
# Channel name       0
# Video Uploads      6
# Subscribers      387
# Video views        0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # 8. Data Cleaning [ Rank Column ]

# %%
df.head(1)
# Out:
#   Rank Grade Channel name Video Uploads Subscribers  Video views
# 0  1st  A++        Zee TV         82757    18752951  20869786591

# %%
df["Rank"] = df["Rank"].str[0:-2]

# %%
df.head(20)
# Out:
#    Rank Grade                Channel name Video Uploads Subscribers  \
# 0     1  A++                       Zee TV         82757    18752951
# 1     2  A++                     T-Series         12661    61196302
# 2     3  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3     4  A++                    SET India         27323    31180559
# 4     5  A++                          WWE         36756    32852346
# 5     6  A++                   Movieclips         30243    17149705
# 6     7  A++                   netd müzik          8500    11373567
# 7     8  A++        ABS-CBN Entertainment        100147    12149206
# 8     9  A++              Ryan ToysReview          1140    16082927
# 9    10  A++                  Zee Marathi         74607     2841811
# 10   11   A+              5-Minute Crafts          2085    33492951
# 11   12   A+              Canal KondZilla           822    39409726
# 12   13   A+             Like Nastya Vlog           150     7662886
# ...

# %%
df.tail(20)
# Out:
#        Rank Grade                      Channel name Video Uploads Subscribers  \
# 4980  4,981   B+                     Screen Junkies           878     6532616
# 4981  4,982   B+                         Luli60able             5      158905
# 4982  4,983   B+                           채널A Home          9876      647435
# 4983  4,984   B+                    Машинка Игрушка           242      219238
# 4984  4,985   B+                             Jean L          2116     2875705
# 4985  4,986   B+                  AndreaBocelliVEVO           191      820381
# 4986  4,987   B+                 CidadeAlertaRecord          7299     1123300
# 4987  4,988   B+                      YouANDi Games          1358     1536819
# 4988  4,989   B+             GREAT IDEAS GREAT LIFE            80     1349511
# 4989  4,990   B+                             Kukuli           219      660742
# 4990  4,991   B+      Ho Ngoc Ha's Official Channel           208         NaN
# ...

# %%
df["Rank"] = df["Rank"].str.replace(",","")

# %%
df["Rank"] = df["Rank"].astype('int')

# %%
df.dtypes
# Out:
# Rank              int64
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %% [markdown]
# # 9. Data Cleaning [ Video Uploads & Subscribers ]

# %%
df.head()
# Out:
#    Rank Grade                Channel name Video Uploads Subscribers  \
# 0     1  A++                       Zee TV         82757    18752951
# 1     2  A++                     T-Series         12661    61196302
# 2     3  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3     4  A++                    SET India         27323    31180559
# 4     5  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
df.isnull().sum()
# Out:
# Rank               0
# Grade              0
# Channel name       0
# Video Uploads      6
# Subscribers      387
# Video views        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dropna(inplace=True)

# %%
df["Video Uploads"] =  df["Video Uploads"].astype('int')
df["Subscribers"] = df["Subscribers"].astype('int')

# %%
df.dtypes
# Out:
# Rank              int64
# Grade            object
# Channel name     object
# Video Uploads     int64
# Subscribers       int64
# Video views       int64
# dtype: object

# %% [markdown]
# # 10. Data Cleaning [ Grade Column ]

# %%
df.dtypes
# Out:
# Rank              int64
# Grade            object
# Channel name     object
# Video Uploads     int64
# Subscribers       int64
# Video views       int64
# dtype: object

# %%
df.head()
# Out:
#    Rank Grade                Channel name  Video Uploads  Subscribers  \
# 0     1  A++                       Zee TV          82757     18752951
# 1     2  A++                     T-Series          12661     61196302
# 2     3  A++   Cocomelon - Nursery Rhymes            373     19238251
# 3     4  A++                    SET India          27323     31180559
# 4     5  A++                          WWE          36756     32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
df["Grade"].unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', 'A- ', 'B+ '], dtype=object)

# %%
df["Grade"] = df["Grade"].map({"A++ ":5, "A+ ":4, "A ":3,"A- ":2, "B+ ":1})

# %%
df.head()
# Out:
#    Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0     1      5                      Zee TV          82757     18752951
# 1     2      5                    T-Series          12661     61196302
# 2     3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3     4      5                   SET India          27323     31180559
# 4     5      5                         WWE          36756     32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %% [markdown]
# # 11. Find Average Views For Each Channel

# %%
df.head()
# Out:
#    Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0     1      5                      Zee TV          82757     18752951
# 1     2      5                    T-Series          12661     61196302
# 2     3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3     4      5                   SET India          27323     31180559
# 4     5      5                         WWE          36756     32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
df["Average Views"] = df["Video views"]/df["Video Uploads"]

# %%
df.head()
# Out:
#    Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0     1      5                      Zee TV          82757     18752951
# 1     2      5                    T-Series          12661     61196302
# 2     3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3     4      5                   SET India          27323     31180559
# 4     5      5                         WWE          36756     32852346
#
#    Video views  Average Views
# 0  20869786591      252181.53
# 1  47548839843     3755535.89
# 2   9793305082    26255509.60
# 3  22675948293      829921.62
# 4  26273668433      714813.05

# %% [markdown]
# # 12. Find Out Top Five Channels With Maximum Number of Video Uploads

# %%
df.head()
# Out:
#    Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0     1      5                      Zee TV          82757     18752951
# 1     2      5                    T-Series          12661     61196302
# 2     3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3     4      5                   SET India          27323     31180559
# 4     5      5                         WWE          36756     32852346
#
#    Video views  Average Views
# 0  20869786591      252181.53
# 1  47548839843     3755535.89
# 2   9793305082    26255509.60
# 3  22675948293      829921.62
# 4  26273668433      714813.05

# %%
top_five = df["Video Uploads"].sort_values(ascending=False).head()

# %%
df.loc[top_five.index, :]
# Out:
#       Rank  Grade Channel name  Video Uploads  Subscribers  Video views  \
# 3453  3454      1   AP Archive         422326       746325    548619569
# 1149  1150      2     YTN NEWS         355996       820108   1640347646
# 2223  2224      1    SBS Drama         335521      1418619   1565758044
# 323    324      3     GMA News         269065      2599175   2786949164
# 2956  2957      1          MLB         267649      1434206   1329206392
#
#       Average Views
# 3453        1299.04
# 1149        4607.77
# 2223        4666.65
# 323        10357.90
# 2956        4966.23

# %%
# Direct way 
df.sort_values(by="Video Uploads", ascending = False).head()
# Out:
#       Rank  Grade Channel name  Video Uploads  Subscribers  Video views  \
# 3453  3454      1   AP Archive         422326       746325    548619569
# 1149  1150      2     YTN NEWS         355996       820108   1640347646
# 2223  2224      1    SBS Drama         335521      1418619   1565758044
# 323    324      3     GMA News         269065      2599175   2786949164
# 2956  2957      1          MLB         267649      1434206   1329206392
#
#       Average Views
# 3453        1299.04
# 1149        4607.77
# 2223        4666.65
# 323        10357.90
# 2956        4966.23

# %% [markdown]
# # 13. Find Correlation Matrix

# %%
df.corr() # An error occurs because all dtypes are not numbers. So let's fix it.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[296], line 1
# ----> 1 df.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
df.dtypes
# Out:
# Rank               int64
# Grade              int64
# Channel name      object
# Video Uploads      int64
# Subscribers        int64
# Video views        int64
# Average Views    float64
# dtype: object

# %%
numeric_data = df.select_dtypes(include='number')
correlation_matrix=numeric_data.corr()
correlation_matrix
# Out:
#                Rank  Grade  Video Uploads  Subscribers  Video views  \
# Rank           1.00  -0.87          -0.07        -0.38        -0.40
# Grade         -0.87   1.00           0.09         0.43         0.48
# Video Uploads -0.07   0.09           1.00         0.01         0.09
# Subscribers   -0.38   0.43           0.01         1.00         0.79
# Video views   -0.40   0.48           0.09         0.79         1.00
# Average Views -0.15   0.16          -0.06         0.29         0.29
#
#                Average Views
# Rank                   -0.15
# Grade                   0.16
# Video Uploads          -0.06
# Subscribers             0.29
# Video views             0.29
# Average Views           1.00

# %% [markdown]
# # 14.  Which Grade Has A Maximum Number of Video Uploads?

# %%
sns.barplot(data=df, x="Grade", y="Video Uploads")
# Out:
# <Axes: xlabel='Grade', ylabel='Video Uploads'>

# %% [markdown]
# # 15.Which Grade Has The Highest Average Views?

# %%
df.head()
# Out:
#    Rank  Grade                Channel name  Video Uploads  Subscribers  \
# 0     1      5                      Zee TV          82757     18752951
# 1     2      5                    T-Series          12661     61196302
# 2     3      5  Cocomelon - Nursery Rhymes            373     19238251
# 3     4      5                   SET India          27323     31180559
# 4     5      5                         WWE          36756     32852346
#
#    Video views  Average Views
# 0  20869786591      252181.53
# 1  47548839843     3755535.89
# 2   9793305082    26255509.60
# 3  22675948293      829921.62
# 4  26273668433      714813.05

# %%
df.groupby("Grade")["Average Views"].mean()
# Out:
# Grade
# 1    3280380.88
# 2    5254804.04
# 3   10540908.45
# 4   11577080.32
# 5    5688267.96
# Name: Average Views, dtype: float64

# %%
sns.barplot(data=df, x="Grade", y="Average Views")
# Out:
# <Axes: xlabel='Grade', ylabel='Average Views'>

# %% [markdown]
# # 16.  Which Grade Has The Highest Number of Subscribers?

# %%
df.head(1)
# Out:
#    Rank  Grade Channel name  Video Uploads  Subscribers  Video views  \
# 0     1      5       Zee TV          82757     18752951  20869786591
#
#    Average Views
# 0      252181.53

# %%
df.groupby("Grade")["Subscribers"].mean().sort_values(ascending=False)
# Out:
# Grade
# 5   22281762.50
# 4   11726947.47
# 3    5107136.29
# 2    2798520.38
# 1    1535207.95
# Name: Subscribers, dtype: float64

# %%
sns.barplot(data=df, x="Grade",y="Subscribers")
# Out:
# <Axes: xlabel='Grade', ylabel='Subscribers'>

# %% [markdown]
# # 17. Which Grade Has The Highest Video Views?

# %%
df.head(1)
# Out:
#    Rank  Grade Channel name  Video Uploads  Subscribers  Video views  \
# 0     1      5       Zee TV          82757     18752951  20869786591
#
#    Average Views
# 0      252181.53

# %%
sns.barplot(data=df, x="Grade", y="Video views")
# Out:
# <Axes: xlabel='Grade', ylabel='Video views'>
